# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd drive/My\ Drive/IRE/mini_project
# !pwd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: 'drive/My Drive/IRE/mini_project'
# /content/drive/My Drive/IRE/mini_project
# /content/drive/My Drive/IRE/mini_project

# %%
# !bash final_search.sh right_etbig_inverted_indexes/inv_indexes/ queries.txt
# Out:
# Requirement already satisfied: pystemmer in /usr/local/lib/python3.7/dist-packages (2.0.1)
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Opening files ...
#
# ########################################################################
# Billie Jean michael jackson
#
# ******** Search Results ********
# rank: 0 	page_id: 193585 	total_words_in_page: 8277 	title: Billie Jean
# rank: 1 	page_id: 6322959 	total_words_in_page: 8194 	title: King of Pop (album)
# rank: 2 	page_id: 5107230 	total_words_in_page: 24113 	title: Michael Jackson
# rank: 3 	page_id: 356853 	total_words_in_page: 11495 	title: Thriller (album)
# rank: 4 	page_id: 4739555 	total_words_in_page: 65858 	title: Wikipedia:WikiProject Canadian football/Articles
# rank: 5 	page_id: 4116647 	total_words_in_page: 11767 	title: List of awards and nominations received by Michael Jackson
# rank: 6 	page_id: 779282 	total_words_in_page: 35848 	title: List of Soul Train episodes
# rank: 7 	page_id: 9893456 	total_words_in_page: 4364 	title: List of cover versions of Michael Jackson songs
# rank: 8 	page_id: 6323387 	total_words_in_page: 5135 	title: Thriller 25
# rank: 9 	page_id: 8960491 	total_words_in_page: 78987 	title: Wikipedia:WikiProject Rugby league/Articles
# rank: 10 	page_id: 8869870 	total_words_in_page: 98225 	title: Wikipedia:WikiProject Deletion sorting/Sportspeople/archive
#
# Search time: 7.80388879776001
#
# ########################################################################
# b:Marc Spector i:Marvel Comics c:1980 comics debuts
#
# ******** Search Results ********
# rank: 0 	page_id: 528740 	total_words_in_page: 8688 	title: Moon Knight
# rank: 1 	page_id: 501923 	total_words_in_page: 29279 	title: List of Marvel Comics first appearances
# rank: 2 	page_id: 2068639 	total_words_in_page: 25067 	title: Publication history of Marvel Comics crossover events
# rank: 3 	page_id: 11650314 	total_words_in_page: 18404 	title: Marvel NOW!
# rank: 4 	page_id: 784323 	total_words_in_page: 2432 	title: Cobra (Marvel Comics)
# rank: 5 	page_id: 195860 	total_words_in_page: 15307 	title: Wolverine (character)
# rank: 6 	page_id: 10541390 	total_words_in_page: 16211 	title: List of Marvel Comics superhero debuts
# rank: 7 	page_id: 6252497 	total_words_in_page: 14662 	title: Norman Osborn
# rank: 8 	page_id: 2154841 	total_words_in_page: 2263 	title: List of Ultimate Marvel characters
# rank: 9 	page_id: 4276873 	total_words_in_page: 8683 	title: Marvel Omnibus
# rank: 10 	page_id: 1222858 	total_words_in_page: 8611 	title: List of superhero debuts
#
# Search time: 1.8829357624053955
#
# ########################################################################
# Allan Rune Pettersson
#
# ******** Search Results ********
# rank: 0 	page_id: 625658 	total_words_in_page: 4376 	title: Allan Pettersson
# rank: 1 	page_id: 2865277 	total_words_in_page: 158 	title: Allan Rune Pettersson
# rank: 2 	page_id: 14274546 	total_words_in_page: 29797 	title: List of former members of the Riksdag
# rank: 3 	page_id: 6315020 	total_words_in_page: 13167 	title: List of Swedish Olympic medalists
# rank: 4 	page_id: 5912017 	total_words_in_page: 288 	title: Pettersson
# rank: 5 	page_id: 4567557 	total_words_in_page: 4936 	title: List of Swedish Swimming Championships champions (men)
# rank: 6 	page_id: 14274491 	total_words_in_page: 36445 	title: List of members of the upper house of the Riksdag
# rank: 7 	page_id: 1124253 	total_words_in_page: 81726 	title: Wikipedia:WikiProject Red Link Recovery/Exceptions
# rank: 8 	page_id: 8382586 	total_words_in_page: 625 	title: Symphony No. 9 (Pettersson)
# rank: 9 	page_id: 11278928 	total_words_in_page: 3253 	title: 2012 Åtvidabergs FF season
# rank: 10 	page_id: 493317 	total_words_in_page: 4791 	title: Runes
#
# Search time: 0.21023130416870117
#
# ########################################################################
# b:angus r:tories i:James Lee
#
# ******** Search Results ********
# rank: 0 	page_id: 10782476 	total_words_in_page: 24508 	title: Wikipedia:WikiProject Spam/LinkReports/erg.environics.net
# rank: 1 	page_id: 1728932 	total_words_in_page: 23909 	title: List of Great Britain and UK Parliament constituencies in Scotland from 1707
# rank: 2 	page_id: 4568646 	total_words_in_page: 98868 	title: Wikipedia:WikiProject Deletion sorting/Actors and filmmakers/archive
# rank: 3 	page_id: 172459 	total_words_in_page: 34386 	title: Wikipedia:Upload log archive/June 2003
# rank: 4 	page_id: 13180926 	total_words_in_page: 98090 	title: Wikipedia:WikiProject Deletion sorting/People/archive 2
# rank: 5 	page_id: 10808499 	total_words_in_page: 68288 	title: Wikipedia:WikiProject Australia/Statistics/24 November 2011
# rank: 6 	page_id: 10015368 	total_words_in_page: 23445 	title: Lockheed Martin F-35 Lightning II Canadian procurement
# rank: 7 	page_id: 12302769 	total_words_in_page: 123525 	title: Wikipedia:GLAM/Your paintings/Painters born 1940-1959
# rank: 8 	page_id: 14619102 	total_words_in_page: 26991 	title: 2019 United Kingdom general election
# rank: 9 	page_id: 4739555 	total_words_in_page: 65858 	title: Wikipedia:WikiProject Canadian football/Articles
# rank: 10 	page_id: 9431232 	total_words_in_page: 23422 	title: List of elected British politicians who have changed party affiliation
#
# Search time: 2.605665922164917
#
# ########################################################################
# uss conolly
#
# ******** Search Results ********
# rank: 0 	page_id: 267599 	total_words_in_page: 9038 	title: List of destroyers of the United States Navy
# rank: 1 	page_id: 338935 	total_words_in_page: 1074 	title: USS Conolly
# rank: 2 	page_id: 6591457 	total_words_in_page: 22792 	title: Wikipedia:WikiProject Ships/Articles US
# rank: 3 	page_id: 7354583 	total_words_in_page: 800 	title: Richard L. Conolly
# rank: 4 	page_id: 934510 	total_words_in_page: 5589 	title: List of United States Navy ships: C
# rank: 5 	page_id: 442969 	total_words_in_page: 25072 	title: List of auxiliaries of the United States Navy
# rank: 6 	page_id: 5810388 	total_words_in_page: 16657 	title: Index of World War II articles (U)
# rank: 7 	page_id: 451046 	total_words_in_page: 7549 	title: List of patrol vessels of the United States Navy
# rank: 8 	page_id: 934508 	total_words_in_page: 7148 	title: List of United States Navy ships: A–B
# rank: 9 	page_id: 5939347 	total_words_in_page: 1239 	title: Wikipedia:WikiProject Military history/Assessment/Tag & Assess 2008/141
# rank: 10 	page_id: 451009 	total_words_in_page: 6634 	title: List of mine warfare vessels of the United States Navy
#
# Search time: 0.14000511169433594
#
# ########################################################################
# b:Speed of Light c:Concepts in Physics
#
# ******** Search Results ********
# rank: 0 	page_id: 7897588 	total_words_in_page: 48759 	title: Wikipedia:Arbitration/Requests/Case/Speed of light/Workshop
# rank: 1 	page_id: 2134969 	total_words_in_page: 105820 	title: Wikipedia:Reference desk/Archives/Science/April 2006
# rank: 2 	page_id: 2260171 	total_words_in_page: 90583 	title: Wikipedia:Reference desk/Archives/Science/May 2006
# rank: 3 	page_id: 1776806 	total_words_in_page: 118123 	title: Wikipedia:Reference desk/Archives/Science/January 2006
# rank: 4 	page_id: 1671205 	total_words_in_page: 79910 	title: Wikipedia:Reference desk/Archives/Science/December 2005
# rank: 5 	page_id: 1455052 	total_words_in_page: 101927 	title: Wikipedia:Reference desk/Archives/Science/October 2005
# rank: 6 	page_id: 18774 	total_words_in_page: 11206 	title: Speed of light
# rank: 7 	page_id: 2014065 	total_words_in_page: 92028 	title: Wikipedia:Reference desk/Archives/Science/March 2006
# rank: 8 	page_id: 11605995 	total_words_in_page: 32430 	title: Glossary of engineering
# rank: 9 	page_id: 17612 	total_words_in_page: 11592 	title: Special relativity
# rank: 10 	page_id: 18792 	total_words_in_page: 16666 	title: Spacetime
#
# Search time: 2.9943692684173584
#
# ########################################################################
# The Capture 1950
#
# ******** Search Results ********
# rank: 0 	page_id: 9817147 	total_words_in_page: 64 	title: File:Green prior to the capture of Pakchon Oct 1950.PNG
# rank: 1 	page_id: 10730601 	total_words_in_page: 25931 	title: List of ships captured in the 18th century
# rank: 2 	page_id: 7816856 	total_words_in_page: 3262 	title: Battle of Chongju (1950)
# rank: 3 	page_id: 9493389 	total_words_in_page: 2958 	title: Battle of Sangju (1950)
# rank: 4 	page_id: 13244663 	total_words_in_page: 12571 	title: Timeline of women in warfare in the United States from 1950 to 1999
# rank: 5 	page_id: 12065514 	total_words_in_page: 3198 	title: May 1950
# rank: 6 	page_id: 6386451 	total_words_in_page: 8120 	title: 1950
# rank: 7 	page_id: 3194580 	total_words_in_page: 973 	title: Odette (1950 film)
# rank: 8 	page_id: 12184008 	total_words_in_page: 3678 	title: June 1950
# rank: 9 	page_id: 11999380 	total_words_in_page: 4062 	title: April 1950
# rank: 10 	page_id: 10421528 	total_words_in_page: 5742 	title: Wikipedia:GLAM/National Maritime Museum/Warship Histories Done/File 1
#
# Search time: 0.5475015640258789
#
# ########################################################################
# t:birdseye b:tarantula
#
# ******** Search Results ********
# rank: 0 	page_id: 6166900 	total_words_in_page: 5356 	title: Tarantula
# rank: 1 	page_id: 6742723 	total_words_in_page: 782 	title: Tom Birdseye
# rank: 2 	page_id: 1055687 	total_words_in_page: 11205 	title: List of most massive stars
# rank: 3 	page_id: 2519829 	total_words_in_page: 10915 	title: List of most luminous stars
# rank: 4 	page_id: 13975913 	total_words_in_page: 1878 	title: Hemipepsis ustulata
# rank: 5 	page_id: 2067534 	total_words_in_page: 1421 	title: Black Tarantula
# rank: 6 	page_id: 1884116 	total_words_in_page: 228 	title: Tarantula (disambiguation)
# rank: 7 	page_id: 761162 	total_words_in_page: 1267 	title: Tarantula (DC Comics)
# rank: 8 	page_id: 201446 	total_words_in_page: 1187 	title: Tarantula Nebula
# rank: 9 	page_id: 7340017 	total_words_in_page: 628 	title: Texas brown tarantula
# rank: 10 	page_id: 2421586 	total_words_in_page: 466 	title: The Tarantulas
#
# Search time: 0.011766910552978516
#
# ########################################################################
# 4 July 1776
#
# ******** Search Results ********
# rank: 0 	page_id: 3265772 	total_words_in_page: 4093 	title: 1776
# rank: 1 	page_id: 14245679 	total_words_in_page: 8133 	title: List of shipwrecks in 1776
# rank: 2 	page_id: 8047688 	total_words_in_page: 1899 	title: 1776 in the United States
# rank: 3 	page_id: 4069746 	total_words_in_page: 3523 	title: 1776 (film)
# rank: 4 	page_id: 7837697 	total_words_in_page: 1874 	title: HMS Camilla (1776)
# rank: 5 	page_id: 576497 	total_words_in_page: 134 	title: Wikipedia:Articles for deletion/George Washington July 9 1776 General Orders
# rank: 6 	page_id: 9808793 	total_words_in_page: 752 	title: Wikipedia:London Gazette Index/17/1776
# rank: 7 	page_id: 117263 	total_words_in_page: 4970 	title: 1776 (musical)
# rank: 8 	page_id: 9110510 	total_words_in_page: 1795 	title: List of Continental Army units (1776)
# rank: 9 	page_id: 3860095 	total_words_in_page: 1214 	title: 1776 in Great Britain
# rank: 10 	page_id: 10241792 	total_words_in_page: 1280 	title: HMS Shark (1776)
#
# Search time: 3.897928476333618

# %%
# !pip install pystemmer
# !python nltk_download.py
# Out:
# Requirement already satisfied: pystemmer in /usr/local/lib/python3.7/dist-packages (2.0.1)
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
import nltk
import string
from Stemmer import Stemmer
from nltk.corpus import stopwords as nltk_stopwords
import time
import linecache
import json
import sys
import math
import operator
import heapq

# %%
stopwords = list(nltk_stopwords.words('english'))
stemmer = Stemmer('english')
total_docs = 14764785 #21350000
min_words_in_doc = 20
field_weight = 5
title_weight = 10
doc_length_dict = []
index_length_dict = []
min_word_len = 3
offsets = []
index_files = []

# %%
def open_files():
    global index_length_dict, doc_length_dict, offsets, index_files
    ## read title_index and store docid with num of words
    with open(vocab_dir+'/title_index.txt') as f1:
        for line in f1:
            docid, title, num_words = line.strip().split('|')
            doc_length_dict.append(int(num_words.strip()))
    for a in ['0']+list(string.ascii_lowercase):
        cur_offs = []
        with open(vocab_dir+'/invoffset_'+a+'.txt') as f:
            for line in f:
                cur_offs.append(int(line.strip()))
        offsets.append(cur_offs)
        idx_file = open(vocab_dir+'/invindex_'+a+'.txt') 
        index_files.append(idx_file)
    ## read meta_invindex to get how many lines each file has
    for offs in offsets:
        index_length_dict.append(len(offs))
    print(len(doc_length_dict),len(index_length_dict),len(offsets))

def close_files():
    global index_files
    for idf in index_files:
        idf.close()

# %%
def binary_search(l, r, w, fpath, idx):
    while r >= l:
        mid = (l + r) // 2
        # cur_line = linecache.getline(fpath,mid).strip()
        index_files[idx].seek(offsets[idx][mid])
        cur_line = index_files[idx].readline()
        cur_word = cur_line.split('|',1)[0]
        if  cur_word == w:
            return cur_line
        elif cur_word > w:
            r = mid-1
        else:
            l = mid+1
    return -1

def search_word(orgword,section):
    global default_res, total_docs, min_words_in_doc, field_weight, doc_length_dict, doc_score_dict, min_word_len
    if len(orgword) < min_word_len:
        return 
    word = orgword
    if word in stopwords:
        return
    word = stemmer.stemWord(word)
    char1 = word[0]
    if char1.isnumeric():
        idx = 0
        char1 = '0'
    else:
        idx = ord(char1)-ord('a')+1
    cur_line = binary_search(0,index_length_dict[idx],word,vocab_dir+"/invindex_"+char1+".txt",idx)
    if cur_line == -1:
        return
    cur_list = cur_line.split('|')
    term_idf = math.log(total_docs / len(cur_list))
    if not cur_list[0] == word:
        return
    term_all_score = 0
    for i in range(1,len(cur_list)):
        cur_id, cur_cnts = cur_list[i].split(';',1) 
        cur_id = int(cur_id.strip())
        if doc_length_dict[cur_id] < min_words_in_doc:
            continue
        cur_cnts = cur_cnts.split(';')
        cur_score = 0  ## current document's score
        for cnt in cur_cnts:
            if 't' in cnt:
                c = int(cnt.split('t')[1])
                cur_score += title_weight * c
                if 't' in section:
                    cur_score += field_weight * c
            if 'b' in cnt:
                c = int(cnt.split('b')[1])
                cur_score += c
                if 'b' in section:
                    cur_score += field_weight * c
            if 'i' in cnt:
                c = int(cnt.split('i')[1])
                cur_score += c
                if 'i' in section:
                    cur_score += field_weight * c
            if 'c' in cnt:
                c = int(cnt.split('c')[1])
                cur_score += c
                if 'c' in section:
                    cur_score += field_weight * c
            if 'l' in cnt:
                c = int(cnt.split('l')[1])
                cur_score += c
                if 'l' in section:
                    cur_score += field_weight * c
        term_freq = math.log(1+cur_score)
        cur_score = term_freq * term_idf
        if cur_id not in doc_score_dict:
            doc_score_dict[cur_id] = cur_score
        else:
            doc_score_dict[cur_id] += cur_score
        term_all_score += cur_score
    print("Score for word ",orgword,":",term_all_score) 


def search_query(query):
    global doc_score_dict, min_word_len
    query = query.strip().lower()
    qwlist = [e.strip()+':' for i,e in enumerate(query.strip().split(':')) if e]
    qwlist[-1] = qwlist[-1][:-1]
    query_dict = {}
    field = '0'
    for qry in qwlist: 
        for w in qry.split(' '):
            if not w:
                continue
            if ':' in w:
                field = w.split(':')[0].strip()
                if field not in ['t', 'b', 'c', 'i', 'l']:
                    field = 'b'
                cw = ''
            else:
                cw = w.strip()
            if cw:
                # search_word(cw,field)
                if cw not in query_dict:
                    query_dict[cw] = field
                else:
                    query_dict[cw] += field
                cw = ""
    for qw, qf in query_dict.items():
        print(qw,qf)
        search_word(qw,qf)
    # doc_score_dict = dict( sorted(doc_score_dict.items(), key=operator.itemgetter(1), reverse=True))
        

def print_results(topk=12):
    global doc_score_dict, vocab_dir
    print("\n******** Search Results ********")
    top_pages = heapq.nlargest(topk, doc_score_dict, key=doc_score_dict.get)
    i = 0
    for docid in top_pages:
        cur_line = linecache.getline(vocab_dir+"/title_index.txt",docid+1).strip()
        cur_id, cur_title, cur_words = cur_line.split('|')
        cur_id = int(cur_id)
        if cur_id != docid:
            err = math.abs(cur_id - docid) + 1
            cur_line = binary_search(cur_id-err, cur_id+err, str(doc_id), vocab_dir+"/title_index.txt")
            cur_id, cur_title, cur_words = cur_line.split('|')
        print("rank:",i,"\tpage_id:",cur_id,"\ttotal_words_in_page:",cur_words,"\ttitle:",cur_title)
        if i==10:
            return
        i += 1

# %%
global vocab_dir
vocab_dir = "right_etbig_inverted_indexes/inv_indexes/"
open_files()
# Out:
# 14766628 27 27

# %%
test_qlist = []
with open("queries.txt") as qfile:
    for line in qfile:
        test_qlist.append(line.strip())

# %%
# in_query = "b:Marc Spector i:Marvel Comics c:1980 comics debuts"
global doc_score_dict
for in_query in test_qlist:
    print("\n########################################################################")
    print(in_query)
    doc_score_dict = {}
    start = time.time()
    search_query(in_query.strip())
    print_results(12)
    print("\nSearch time:",time.time()-start)
# Out:
# ########################################################################
# Billie Jean michael jackson
# billie 0
# Score for word  billie : 559812.7918110351
# jean 0
# Score for word  jean : 973417.0319327948
# michael 0
# Score for word  michael : 1982134.6812941008
# jackson 0
# Score for word  jackson : 781581.9339835476
#
# ******** Search Results ********
# rank: 0 	page_id: 193585 	total_words_in_page: 8277 	title: Billie Jean
# rank: 1 	page_id: 6322959 	total_words_in_page: 8194 	title: King of Pop (album)
# rank: 2 	page_id: 5107230 	total_words_in_page: 24113 	title: Michael Jackson
# rank: 3 	page_id: 356853 	total_words_in_page: 11495 	title: Thriller (album)
# rank: 4 	page_id: 4739555 	total_words_in_page: 65858 	title: Wikipedia:WikiProject Canadian football/Articles
# rank: 5 	page_id: 4116647 	total_words_in_page: 11767 	title: List of awards and nominations received by Michael Jackson
# rank: 6 	page_id: 779282 	total_words_in_page: 35848 	title: List of Soul Train episodes
# rank: 7 	page_id: 9893456 	total_words_in_page: 4364 	title: List of cover versions of Michael Jackson songs
# rank: 8 	page_id: 6323387 	total_words_in_page: 5135 	title: Thriller 25
# rank: 9 	page_id: 8960491 	total_words_in_page: 78987 	title: Wikipedia:WikiProject Rugby league/Articles
# rank: 10 	page_id: 8869870 	total_words_in_page: 98225 	title: Wikipedia:WikiProject Deletion sorting/Sportspeople/archive
#
# Search time: 2.8635005950927734
#
# ########################################################################
# b:Marc Spector i:Marvel Comics c:1980 comics debuts
# marc b
# Score for word  marc : 1015737.4947135994
# spector b
# Score for word  spector : 81227.2861192985
# marvel i
# Score for word  marvel : 287455.79231074615
# comics ic
# Score for word  comics : 1022655.0073528416
# 1980 c
# Score for word  1980 : 54587.20329385577
# debuts c
# Score for word  debuts : 1563110.8238551677
#
# ******** Search Results ********
# rank: 0 	page_id: 528740 	total_words_in_page: 8688 	title: Moon Knight
# rank: 1 	page_id: 501923 	total_words_in_page: 29279 	title: List of Marvel Comics first appearances
# rank: 2 	page_id: 2068639 	total_words_in_page: 25067 	title: Publication history of Marvel Comics crossover events
# rank: 3 	page_id: 11650314 	total_words_in_page: 18404 	title: Marvel NOW!
# rank: 4 	page_id: 784323 	total_words_in_page: 2432 	title: Cobra (Marvel Comics)
# rank: 5 	page_id: 195860 	total_words_in_page: 15307 	title: Wolverine (character)
# rank: 6 	page_id: 10541390 	total_words_in_page: 16211 	title: List of Marvel Comics superhero debuts
# rank: 7 	page_id: 6252497 	total_words_in_page: 14662 	title: Norman Osborn
# rank: 8 	page_id: 2154841 	total_words_in_page: 2263 	title: List of Ultimate Marvel characters
# rank: 9 	page_id: 4276873 	total_words_in_page: 8683 	title: Marvel Omnibus
# rank: 10 	page_id: 1222858 	total_words_in_page: 8611 	title: List of superhero debuts
#
# Search time: 2.0202503204345703
#
# ########################################################################
# Allan Rune Pettersson
# allan 0
# Score for word  allan : 353744.8163653109
# rune 0
# Score for word  rune : 63689.31671586219
# pettersson 0
# Score for word  pettersson : 19809.745796072963
#
# ******** Search Results ********
# rank: 0 	page_id: 625658 	total_words_in_page: 4376 	title: Allan Pettersson
# rank: 1 	page_id: 2865277 	total_words_in_page: 158 	title: Allan Rune Pettersson
# rank: 2 	page_id: 14274546 	total_words_in_page: 29797 	title: List of former members of the Riksdag
# rank: 3 	page_id: 6315020 	total_words_in_page: 13167 	title: List of Swedish Olympic medalists
# rank: 4 	page_id: 5912017 	total_words_in_page: 288 	title: Pettersson
# rank: 5 	page_id: 4567557 	total_words_in_page: 4936 	title: List of Swedish Swimming Championships champions (men)
# rank: 6 	page_id: 14274491 	total_words_in_page: 36445 	title: List of members of the upper house of the Riksdag
# rank: 7 	page_id: 1124253 	total_words_in_page: 81726 	title: Wikipedia:WikiProject Red Link Recovery/Exceptions
# rank: 8 	page_id: 8382586 	total_words_in_page: 625 	title: Symphony No. 9 (Pettersson)
# rank: 9 	page_id: 11278928 	total_words_in_page: 3253 	title: 2012 Åtvidabergs FF season
# rank: 10 	page_id: 493317 	total_words_in_page: 4791 	title: Runes
#
# Search time: 0.26065492630004883
#
# ########################################################################
# b:angus r:tories i:James Lee
# angus b
# Score for word  angus : 378038.7225598931
# tories b
# Score for word  tories : 329815.59887351317
# james i
# Score for word  james : 2369128.027569168
# lee i
# Score for word  lee : 1214416.5144191347
#
# ******** Search Results ********
# rank: 0 	page_id: 10782476 	total_words_in_page: 24508 	title: Wikipedia:WikiProject Spam/LinkReports/erg.environics.net
# rank: 1 	page_id: 1728932 	total_words_in_page: 23909 	title: List of Great Britain and UK Parliament constituencies in Scotland from 1707
# rank: 2 	page_id: 4568646 	total_words_in_page: 98868 	title: Wikipedia:WikiProject Deletion sorting/Actors and filmmakers/archive
# rank: 3 	page_id: 172459 	total_words_in_page: 34386 	title: Wikipedia:Upload log archive/June 2003
# rank: 4 	page_id: 13180926 	total_words_in_page: 98090 	title: Wikipedia:WikiProject Deletion sorting/People/archive 2
# rank: 5 	page_id: 10808499 	total_words_in_page: 68288 	title: Wikipedia:WikiProject Australia/Statistics/24 November 2011
# rank: 6 	page_id: 10015368 	total_words_in_page: 23445 	title: Lockheed Martin F-35 Lightning II Canadian procurement
# rank: 7 	page_id: 12302769 	total_words_in_page: 123525 	title: Wikipedia:GLAM/Your paintings/Painters born 1940-1959
# rank: 8 	page_id: 14619102 	total_words_in_page: 26991 	title: 2019 United Kingdom general election
# rank: 9 	page_id: 4739555 	total_words_in_page: 65858 	title: Wikipedia:WikiProject Canadian football/Articles
# rank: 10 	page_id: 9431232 	total_words_in_page: 23422 	title: List of elected British politicians who have changed party affiliation
#
# Search time: 2.5636582374572754
#
# ########################################################################
# uss conolly
# uss 0
# Score for word  uss : 410670.6888332086
# conolly 0
# Score for word  conolly : 10205.180088555579
#
# ******** Search Results ********
# rank: 0 	page_id: 267599 	total_words_in_page: 9038 	title: List of destroyers of the United States Navy
# rank: 1 	page_id: 338935 	total_words_in_page: 1074 	title: USS Conolly
# rank: 2 	page_id: 6591457 	total_words_in_page: 22792 	title: Wikipedia:WikiProject Ships/Articles US
# rank: 3 	page_id: 7354583 	total_words_in_page: 800 	title: Richard L. Conolly
# rank: 4 	page_id: 934510 	total_words_in_page: 5589 	title: List of United States Navy ships: C
# rank: 5 	page_id: 442969 	total_words_in_page: 25072 	title: List of auxiliaries of the United States Navy
# rank: 6 	page_id: 5810388 	total_words_in_page: 16657 	title: Index of World War II articles (U)
# rank: 7 	page_id: 451046 	total_words_in_page: 7549 	title: List of patrol vessels of the United States Navy
# rank: 8 	page_id: 934508 	total_words_in_page: 7148 	title: List of United States Navy ships: A–B
# rank: 9 	page_id: 5939347 	total_words_in_page: 1239 	title: Wikipedia:WikiProject Military history/Assessment/Tag & Assess 2008/141
# rank: 10 	page_id: 451009 	total_words_in_page: 6634 	title: List of mine warfare vessels of the United States Navy
#
# Search time: 0.19500422477722168
#
# ########################################################################
# b:Speed of Light c:Concepts in Physics
# speed b
# Score for word  speed : 1999351.8238812364
# of b
# light b
# Score for word  light : 3480800.5000514663
# concepts c
# Score for word  concepts : 868364.1105845136
# in c
# physics c
# Score for word  physics : 1077616.177082509
#
# ******** Search Results ********
# rank: 0 	page_id: 7897588 	total_words_in_page: 48759 	title: Wikipedia:Arbitration/Requests/Case/Speed of light/Workshop
# rank: 1 	page_id: 2134969 	total_words_in_page: 105820 	title: Wikipedia:Reference desk/Archives/Science/April 2006
# rank: 2 	page_id: 2260171 	total_words_in_page: 90583 	title: Wikipedia:Reference desk/Archives/Science/May 2006
# rank: 3 	page_id: 1776806 	total_words_in_page: 118123 	title: Wikipedia:Reference desk/Archives/Science/January 2006
# rank: 4 	page_id: 1671205 	total_words_in_page: 79910 	title: Wikipedia:Reference desk/Archives/Science/December 2005
# rank: 5 	page_id: 1455052 	total_words_in_page: 101927 	title: Wikipedia:Reference desk/Archives/Science/October 2005
# rank: 6 	page_id: 18774 	total_words_in_page: 11206 	title: Speed of light
# rank: 7 	page_id: 2014065 	total_words_in_page: 92028 	title: Wikipedia:Reference desk/Archives/Science/March 2006
# rank: 8 	page_id: 11605995 	total_words_in_page: 32430 	title: Glossary of engineering
# rank: 9 	page_id: 17612 	total_words_in_page: 11592 	title: Special relativity
# rank: 10 	page_id: 18792 	total_words_in_page: 16666 	title: Spacetime
#
# Search time: 3.1239306926727295
#
# ########################################################################
# The Capture 1950
# the 0
# capture 0
# Score for word  capture : 833389.2326092334
# 1950 0
# Score for word  1950 : 28269.46161638709
#
# ******** Search Results ********
# rank: 0 	page_id: 9817147 	total_words_in_page: 64 	title: File:Green prior to the capture of Pakchon Oct 1950.PNG
# rank: 1 	page_id: 10730601 	total_words_in_page: 25931 	title: List of ships captured in the 18th century
# rank: 2 	page_id: 7816856 	total_words_in_page: 3262 	title: Battle of Chongju (1950)
# rank: 3 	page_id: 9493389 	total_words_in_page: 2958 	title: Battle of Sangju (1950)
# rank: 4 	page_id: 13244663 	total_words_in_page: 12571 	title: Timeline of women in warfare in the United States from 1950 to 1999
# rank: 5 	page_id: 12065514 	total_words_in_page: 3198 	title: May 1950
# rank: 6 	page_id: 6386451 	total_words_in_page: 8120 	title: 1950
# rank: 7 	page_id: 3194580 	total_words_in_page: 973 	title: Odette (1950 film)
# rank: 8 	page_id: 12184008 	total_words_in_page: 3678 	title: June 1950
# rank: 9 	page_id: 11999380 	total_words_in_page: 4062 	title: April 1950
# rank: 10 	page_id: 10421528 	total_words_in_page: 5742 	title: Wikipedia:GLAM/National Maritime Museum/Warship Histories Done/File 1
#
# Search time: 0.5991158485412598
#
# ########################################################################
# t:birdseye b:tarantula
# birdseye t
# Score for word  birdseye : 5159.3711627935345
# tarantula b
# Score for word  tarantula : 45297.277015455096
#
# ******** Search Results ********
# rank: 0 	page_id: 6166900 	total_words_in_page: 5356 	title: Tarantula
# rank: 1 	page_id: 6742723 	total_words_in_page: 782 	title: Tom Birdseye
# rank: 2 	page_id: 1055687 	total_words_in_page: 11205 	title: List of most massive stars
# rank: 3 	page_id: 2519829 	total_words_in_page: 10915 	title: List of most luminous stars
# rank: 4 	page_id: 13975913 	total_words_in_page: 1878 	title: Hemipepsis ustulata
# rank: 5 	page_id: 2067534 	total_words_in_page: 1421 	title: Black Tarantula
# rank: 6 	page_id: 1884116 	total_words_in_page: 228 	title: Tarantula (disambiguation)
# rank: 7 	page_id: 761162 	total_words_in_page: 1267 	title: Tarantula (DC Comics)
# rank: 8 	page_id: 201446 	total_words_in_page: 1187 	title: Tarantula Nebula
# rank: 9 	page_id: 7340017 	total_words_in_page: 628 	title: Texas brown tarantula
# rank: 10 	page_id: 2421586 	total_words_in_page: 466 	title: The Tarantulas
#
# Search time: 0.0493772029876709
#
# ########################################################################
# 4 July 1776
# 4 0
# july 0
# Score for word  july : 4198152.216217007
# 1776 0
# Score for word  1776 : 2946.3936881642603
#
# ******** Search Results ********
# rank: 0 	page_id: 3265772 	total_words_in_page: 4093 	title: 1776
# rank: 1 	page_id: 14245679 	total_words_in_page: 8133 	title: List of shipwrecks in 1776
# rank: 2 	page_id: 8047688 	total_words_in_page: 1899 	title: 1776 in the United States
# rank: 3 	page_id: 4069746 	total_words_in_page: 3523 	title: 1776 (film)
# rank: 4 	page_id: 7837697 	total_words_in_page: 1874 	title: HMS Camilla (1776)
# rank: 5 	page_id: 576497 	total_words_in_page: 134 	title: Wikipedia:Articles for deletion/George Washington July 9 1776 General Orders
# rank: 6 	page_id: 9808793 	total_words_in_page: 752 	title: Wikipedia:London Gazette Index/17/1776
# rank: 7 	page_id: 117263 	total_words_in_page: 4970 	title: 1776 (musical)
# rank: 8 	page_id: 9110510 	total_words_in_page: 1795 	title: List of Continental Army units (1776)
# rank: 9 	page_id: 3860095 	total_words_in_page: 1214 	title: 1776 in Great Britain
# rank: 10 	page_id: 10241792 	total_words_in_page: 1280 	title: HMS Shark (1776)
#
# Search time: 3.939255714416504

# %%
close_files()
